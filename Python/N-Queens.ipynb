# %%
# %autosave 0

# %% [markdown]
# # The 8-Queens Problem

# %% [markdown]
# The <a href="https://en.wikipedia.org/wiki/Eight_queens_puzzle">eight queens puzzle</a> is the problem of placing eight chess queens on a chessboard so that no two queens can capture each other.  In <a href="https://en.wikipedia.org/wiki/Chess">chess</a> a queen can capture another piece if this piece is either
# <ol>
#     <li>in the same row,</li>
#     <li>in the same column, or</li>
#     <li>in the same diagonal.</li>
# </ol>
# The image below shows a queen in row 3, column 4.  All the locations where a piece can be captured by this queen are marked with an arrow.
#
# <img src="queen-captures.png">
#
# We will solve this puzzle by coding it as a formula of propositional logic.  This formula will be solvable iff the eight queens puzzle has a solution.  We will use the algorithm of Davis and Putnam to compute the solution of this formula.

# %%
import davisPutnam as dp

# %% [markdown]
# The function $\texttt{var}(r, c)$ takes a row $r$ and a column $c$ and returns the string $\texttt{'Q(}r\texttt{,}c\texttt{)'}$.  This string is interpreted as a propositional variable specifying that there is a queen in row $r$ and column $c$.  The image below shows how theses variables correspond to the postions on a chess board.
#
# <img src="queens-vars.png">

# %%
def var(row, col):
    return 'Q<' + str(row) + ',' + str(col) + '>'

# %% [markdown]
# Given a set of propositional variables $S$, the function $\texttt{atMostOne}(S)$ returns a set containing a single clause that expresses the fact that at most one of the variables in $S$ is true.

# %%
def atMostOne(S): 
    return { frozenset({('¬',p), ('¬', q)}) for p in S
                                            for q in S 
                                            if  p != q 
           }

# %%
atMostOne({'a', 'b', 'c'})
# Out:
# {frozenset({('¬', 'a'), ('¬', 'c')}),
#  frozenset({('¬', 'b'), ('¬', 'c')}),
#  frozenset({('¬', 'a'), ('¬', 'b')})}

# %% [markdown]
# Given a <tt>row</tt> and the size of the board $n$, the procedure $\texttt{atMostOneInRow}(\texttt{row}, n)$ computes a set of clauses that expresses that there is at most one queen in $\texttt{row}$.

# %%
def atMostOneInRow(row, n):
    return atMostOne({ var(row, col) for col in range(1,n+1) })

# %%
atMostOneInRow(3, 4)
# Out:
# {frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,4>')})}

# %% [markdown]
# Given a column <tt>col</tt> and the size of the board $n$, the procedure $\texttt{oneInColumn}(\texttt{col}, n)$ computes a set of clauses that expresses that there is at least one queen in the column $\texttt{col}$.

# %%
def oneInColumn(col, n):
    return { frozenset({ var(row, col) for row in range(1,n+1) }) }

# %%
oneInColumn(2, 4)
# Out:
# {frozenset({'Q<1,2>', 'Q<2,2>', 'Q<3,2>', 'Q<4,2>'})}

# %% [markdown]
# Given a number $k$ and the size of the board $n$, the procedure $\texttt{atMostOneInFallingDiagonal}(k, n)$ computes a set of clauses that expresses that there is at most one queen in the rising diagonal specified by the equation
# $$ \texttt{row} - \texttt{col} = k. $$

# %%
def atMostOneInFallingDiagonal(k, n):
    S = { var(row, col) for row in range(1, n+1)
                        for col in range(1, n+1) 
                        if  row - col == k 
        }
    return atMostOne(S)

# %%
atMostOneInFallingDiagonal(0, 4)
# Out:
# {frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<2,2>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<4,4>')})}

# %% [markdown]
# Given a number $k$ and the size of the board $n$, the procedure $\texttt{atMostOneInRisingDiagonal}(k, n)$ computes a set of clauses that expresses that there is at most one queen in the rising diagonal specified by the equation
# $$ \texttt{row} + \texttt{col} = k. $$

# %%
def atMostOneInRisingDiagonal(k, n):
    S = { var(row, col) for row in range(1, n+1)
                        for col in range(1, n+1) 
                        if  row + col == k 
        }
    return atMostOne(S)

# %%
atMostOneInRisingDiagonal(0, 3)
# Out:
# set()

# %% [markdown]
# The function $\texttt{allClauses}(n)$ takes the size of the board $n$ and computes a set of clauses that specify that
# <ol>
#     <li>there is at most one queen in every row,</li>
#     <li>there is at most one queen in every rising diagonal,</li>
#     <li>there is at most one queen in every falling diagonal, and</li>
#     <li>there is at least one queen in every column.</li>
# </ol>

# %%
def allClauses(n):
    All = [ atMostOneInRow(row, n)           for row in range(1, n+1)        ] \
        + [ atMostOneInRisingDiagonal(k, n)  for k in range(3, (2*n-1)+1)    ] \
        + [ atMostOneInFallingDiagonal(k, n) for k in range(-(n-2), (n-2)+1) ] \
        + [ oneInColumn(col, n)              for col in range(1, n+1)        ]
    return { clause for S in All for clause in S }

# %%
allClauses(8)
# Out:
# {frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<2,2>')}),
#  frozenset({'Q<1,10>',
#             'Q<10,10>',
#             'Q<2,10>',
#             'Q<3,10>',
#             'Q<4,10>',
#             'Q<5,10>',
#             'Q<6,10>',
#             'Q<7,10>',
#             'Q<8,10>',
#             'Q<9,10>'}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<1,4>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<2,10>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<7,9>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,4>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,2>')}),
#  frozenset({('¬', 'Q<6,8>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<2,4>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<8,6>')}),
#  frozenset({'Q<1,6>',
#             'Q<10,6>',
#             'Q<2,6>',
#             'Q<3,6>',
#             'Q<4,6>',
#             'Q<5,6>',
#             'Q<6,6>',
#             'Q<7,6>',
#             'Q<8,6>',
#             'Q<9,6>'}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<9,3>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,6>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<6,9>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<1,5>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,5>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<4,10>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,4>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<9,5>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,5>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,4>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<3,10>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<2,4>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,5>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<2,2>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<7,7>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,2>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<6,8>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,6>')}),
#  frozenset({('¬', 'Q<3,9>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<9,4>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<8,1>')}),
#  frozenset({'Q<1,3>',
#             'Q<10,3>',
#             'Q<2,3>',
#             'Q<3,3>',
#             'Q<4,3>',
#             'Q<5,3>',
#             'Q<6,3>',
#             'Q<7,3>',
#             'Q<8,3>',
#             'Q<9,3>'}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<9,6>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,3>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<5,1>')}),
#  frozenset({('¬', 'Q<3,9>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,5>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<2,5>')}),
#  frozenset({('¬', 'Q<8,6>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<6,9>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<4,1>')}),
#  frozenset({('¬', 'Q<4,9>'), ('¬', 'Q<5,10>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<3,1>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<2,3>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,3>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<6,9>')}),
#  frozenset({'Q<1,7>',
#             'Q<10,7>',
#             'Q<2,7>',
#             'Q<3,7>',
#             'Q<4,7>',
#             'Q<5,7>',
#             'Q<6,7>',
#             'Q<7,7>',
#             'Q<8,7>',
#             'Q<9,7>'}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,3>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<9,3>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<2,3>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<2,3>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<5,9>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<8,8>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<4,2>')}),
#  frozenset({('¬', 'Q<6,9>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<8,6>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<4,9>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<8,8>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<6,8>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<2,10>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<5,1>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<6,7>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<7,8>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<10,1>')}),
#  frozenset({('¬', 'Q<8,5>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,6>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<9,4>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<7,7>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,4>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<5,1>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<8,7>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<2,5>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<2,5>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,6>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<10,10>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<2,5>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<2,7>')}),
#  frozenset({'Q<1,2>',
#             'Q<10,2>',
#             'Q<2,2>',
#             'Q<3,2>',
#             'Q<4,2>',
#             'Q<5,2>',
#             'Q<6,2>',
#             'Q<7,2>',
#             'Q<8,2>',
#             'Q<9,2>'}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<1,5>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<7,7>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<7,9>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<7,6>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<8,7>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<6,10>')}),
#  frozenset({('¬', 'Q<3,9>'), ('¬', 'Q<4,10>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,2>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<9,7>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<2,1>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,6>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,3>')}),
#  frozenset({('¬', 'Q<9,5>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<7,8>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<6,9>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<7,7>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<6,8>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,2>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<8,8>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<6,1>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<9,3>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<4,2>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<3,9>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<6,10>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,1>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,2>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,1>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,5>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<2,4>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,3>')}),
#  frozenset({('¬', 'Q<5,9>'), ('¬', 'Q<6,10>')}),
#  frozenset({('¬', 'Q<8,5>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<4,2>')}),
#  frozenset({('¬', 'Q<8,6>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<7,7>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<6,1>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,6>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<10,6>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<5,1>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<7,2>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<7,3>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<9,5>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<9,4>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<3,10>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<7,10>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<4,9>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,5>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<6,1>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<5,10>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<8,5>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<9,6>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<8,9>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<5,9>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<3,6>')}),
#  frozenset({'Q<1,4>',
#             'Q<10,4>',
#             'Q<2,4>',
#             'Q<3,4>',
#             'Q<4,4>',
#             'Q<5,4>',
#             'Q<6,4>',
#             'Q<7,4>',
#             'Q<8,4>',
#             'Q<9,4>'}),
#  frozenset({('¬', 'Q<3,4>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<5,10>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,5>')}),
#  frozenset({('¬', 'Q<6,8>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<8,7>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<9,4>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<1,8>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<6,7>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,2>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,7>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<7,7>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<3,9>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<8,5>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<5,9>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,3>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<10,8>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<9,6>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<3,9>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<4,1>')}),
#  frozenset({('¬', 'Q<6,7>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,5>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<2,8>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<1,2>'), ('¬', 'Q<1,4>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<2,1>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<2,7>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<4,9>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<6,1>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<10,5>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<5,6>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<8,4>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,2>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,3>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<4,1>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<7,2>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<5,2>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<10,4>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<6,10>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<8,3>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,1>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<2,9>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,3>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<7,4>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<8,6>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<9,10>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<1,6>')}),
#  frozenset({('¬', 'Q<8,6>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<9,3>')}),
#  frozenset({('¬', 'Q<8,9>'), ('¬', 'Q<9,10>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<6,8>')}),
#  frozenset({'Q<1,1>',
#             'Q<10,1>',
#             'Q<2,1>',
#             'Q<3,1>',
#             'Q<4,1>',
#             'Q<5,1>',
#             'Q<6,1>',
#             'Q<7,1>',
#             'Q<8,1>',
#             'Q<9,1>'}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<5,9>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<8,8>')}),
#  frozenset({'Q<1,9>',
#             'Q<10,9>',
#             'Q<2,9>',
#             'Q<3,9>',
#             'Q<4,9>',
#             'Q<5,9>',
#             'Q<6,9>',
#             'Q<7,9>',
#             'Q<8,9>',
#             'Q<9,9>'}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<1,8>')}),
#  frozenset({('¬', 'Q<1,5>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<8,5>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<9,5>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<9,1>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<4,8>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<6,1>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<3,5>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<7,9>'), ('¬', 'Q<8,8>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<7,1>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<5,10>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<9,7>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<9,3>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<6,10>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,3>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<10,6>'), ('¬', 'Q<9,7>')}),
#  frozenset({('¬', 'Q<1,1>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<1,6>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<6,6>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<8,5>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<8,10>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<6,1>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,2>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<10,5>')}),
#  frozenset({('¬', 'Q<5,7>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<5,1>')}),
#  frozenset({('¬', 'Q<1,3>'), ('¬', 'Q<1,6>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<5,10>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<5,9>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,1>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<3,10>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<2,2>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<5,3>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<8,1>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<4,4>'), ('¬', 'Q<6,2>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,4>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<4,3>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,7>')}),
#  frozenset({('¬', 'Q<2,5>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<6,6>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<7,8>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<8,10>')}),
#  frozenset({('¬', 'Q<6,7>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,7>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<3,1>')}),
#  frozenset({('¬', 'Q<5,4>'), ('¬', 'Q<8,1>')}),
#  frozenset({('¬', 'Q<9,8>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<6,10>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<6,3>'), ('¬', 'Q<7,4>')}),
#  frozenset({('¬', 'Q<3,8>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<5,1>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,1>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<5,5>')}),
#  frozenset({('¬', 'Q<9,4>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<5,6>')}),
#  frozenset({('¬', 'Q<8,2>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<4,6>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<2,1>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<4,10>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<4,7>')}),
#  frozenset({('¬', 'Q<4,10>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,4>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<3,7>'), ('¬', 'Q<6,10>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<4,6>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<10,6>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<6,7>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<4,2>')}),
#  frozenset({('¬', 'Q<1,10>'), ('¬', 'Q<1,1>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<5,3>')}),
#  frozenset({('¬', 'Q<2,6>'), ('¬', 'Q<4,4>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<5,7>')}),
#  frozenset({('¬', 'Q<6,4>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<6,5>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,2>')}),
#  frozenset({('¬', 'Q<8,4>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<9,2>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<2,2>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<9,3>'), ('¬', 'Q<9,4>')}),
#  frozenset({('¬', 'Q<3,6>'), ('¬', 'Q<4,5>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<3,2>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<7,8>')}),
#  frozenset({('¬', 'Q<4,9>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<4,2>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<7,6>')}),
#  frozenset({('¬', 'Q<4,9>'), ('¬', 'Q<5,8>')}),
#  frozenset({('¬', 'Q<6,8>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<5,10>')}),
#  frozenset({('¬', 'Q<10,9>'), ('¬', 'Q<6,5>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<10,4>')}),
#  frozenset({('¬', 'Q<6,7>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<7,1>'), ('¬', 'Q<7,7>')}),
#  frozenset({('¬', 'Q<10,10>'), ('¬', 'Q<10,9>')}),
#  frozenset({('¬', 'Q<8,7>'), ('¬', 'Q<9,8>')}),
#  frozenset({('¬', 'Q<2,9>'), ('¬', 'Q<3,8>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,3>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<7,5>'), ('¬', 'Q<8,6>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<1,7>'), ('¬', 'Q<4,10>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<8,2>')}),
#  frozenset({('¬', 'Q<3,5>'), ('¬', 'Q<3,6>')}),
#  frozenset({('¬', 'Q<3,3>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<8,3>'), ('¬', 'Q<8,5>')}),
#  frozenset({('¬', 'Q<7,8>'), ('¬', 'Q<8,9>')}),
#  frozenset({('¬', 'Q<7,10>'), ('¬', 'Q<7,5>')}),
#  frozenset({('¬', 'Q<10,4>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<5,8>'), ('¬', 'Q<6,9>')}),
#  frozenset({('¬', 'Q<5,5>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<2,4>'), ('¬', 'Q<7,9>')}),
#  frozenset({('¬', 'Q<4,3>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<10,7>'), ('¬', 'Q<5,2>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<9,5>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<1,6>')}),
#  frozenset({('¬', 'Q<3,1>'), ('¬', 'Q<3,9>')}),
#  frozenset({('¬', 'Q<9,3>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<6,2>'), ('¬', 'Q<7,3>')}),
#  frozenset({('¬', 'Q<9,1>'), ('¬', 'Q<9,9>')}),
#  frozenset({('¬', 'Q<10,8>'), ('¬', 'Q<3,1>')}),
#  frozenset({('¬', 'Q<3,10>'), ('¬', 'Q<3,7>')}),
#  frozenset({('¬', 'Q<1,4>'), ('¬', 'Q<1,9>')}),
#  frozenset({('¬', 'Q<6,7>'), ('¬', 'Q<6,8>')}),
#  frozenset({('¬', 'Q<10,2>'), ('¬', 'Q<4,8>')}),
#  frozenset({('¬', 'Q<4,7>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<10,1>'), ('¬', 'Q<10,4>')}),
#  frozenset({('¬', 'Q<4,2>'), ('¬', 'Q<4,9>')}),
#  frozenset({('¬', 'Q<4,1>'), ('¬', 'Q<9,6>')}),
#  frozenset({('¬', 'Q<4,5>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<5,4>')}),
#  frozenset({('¬', 'Q<2,3>'), ('¬', 'Q<2,6>')}),
#  frozenset({('¬', 'Q<2,7>'), ('¬', 'Q<2,8>')}),
#  frozenset({('¬', 'Q<1,9>'), ('¬', 'Q<6,4>')}),
#  frozenset({('¬', 'Q<2,10>'), ('¬', 'Q<2,1>')}),
#  frozenset({('¬', 'Q<10,3>'), ('¬', 'Q<10,6>')}),
#  frozenset({('¬', 'Q<10,5>'), ('¬', 'Q<7,2>')}),
#  ...}

# %% [markdown]
# The set of all clauses contains 512 clauses.  There are 64 variables.

# %%
len(allClauses(10))
# Out:
# 1030

# %% [markdown]
# The function $\texttt{printBoard}(I, n)$ takes a set of unit clauses $I$ that represents a propositional valuation solving the $n$ queens problem and prints the solution represented by $I$.

# %%
def printBoard(I, n):
    if I == { frozenset() }:
        return
    print("-" * (8*n+1))
    for row in range(1, n+1):
        printEmptyLine(n)
        line = "|";
        for col in range(1, n+1):
            if frozenset({ var(row, col) }) in I:
                line += "   Q   |"
            else:
                line += "       |"
        print(line)
        printEmptyLine(n)
        print("-" * (8*n+1))

def printEmptyLine(n):
    line = "|"
    for col in range(1, n+1):
        line += "       |"
    print(line)

# %% [markdown]
# The function $\texttt{queens}(n)$ solves the n queens problem.

# %%
def queens(n):
    "Solve the n queens problem."
    Clauses  = allClauses(n)
    Solution = dp.solve(Clauses, set())
    if Solution != { frozenset() }:
        printBoard(Solution, n)
    else:
        print(f'The problem is not solvable for {n} queens!')

# %%
import time

# %%
start = time.time()
queens(8)
stop  = time.time()
print(f'Time to solve the problem for n = {8}: {round((stop - start)*1000)} milliseconds.\n')

# %% [markdown]
# The fact that it takes less than a second to solve the 8 queens puzzle demonstrates the efficiency of the Davis Putnam procedure.
