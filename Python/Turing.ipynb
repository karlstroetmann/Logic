# %%
from IPython.core.display import display, HTML
HTML('''
     <style>
     .container { width:100% !important; }
     </style>
     ''')

# %%
t1 = '''def simple(x): 
            return 0
     '''

# %%
print(t1)

# %%
exec(t1)

# %%
simple(1)

# %%
t2 = '''def loop(x): 
            while True: 
                x = x + 1
     '''

# %%
exec(t2)

# %%
loop(1)

# %%
t3 = '''def hugo(x): 
            return x++ 
     '''

# %%
exec(t3)

# %%
turing = '''def alan(x):
                result = stops(x, x)
                if result == 1:
                    while True:
                        print("... looping ...")
                return result
         '''

# %%
exec(turing)
