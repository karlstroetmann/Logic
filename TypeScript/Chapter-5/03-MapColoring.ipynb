// %% [markdown]
// # Map Coloring
//
// This short notebook shows how *map coloring* can be formulated as a *constraint satisfaction problem*.
// In map coloring, the goal is to color the states shown in a given map such that no two bordering states
// share the same color.  As an example, consider the map of Australia that is shown below.  Australia
// has seven different states:
// * [Western Australia](https://en.wikipedia.org/wiki/Western_Australia),
// * [Northern Territory](https://en.wikipedia.org/wiki/Northern_Territory),
// * [South Australia](https://en.wikipedia.org/wiki/South_Australia),
// * [Queensland](https://en.wikipedia.org/wiki/Queensland),
// * [New South Wales](https://en.wikipedia.org/wiki/New_South_Wales),
// * [Victoria](https://en.wikipedia.org/wiki/Victoria_(Australia)), and
// * [Tasmania](https://en.wikipedia.org/wiki/Tasmania).
//
// As Tasmania is an island that does not share a border with any of the other states, it can be colored with any given color.
//
// <img src="australia.png" alt="map of australia" width="500">

// %%
import { CSP, Assignment, solve } from "./Backtrack-Solver-Animate";

// %%
type AustralianState = 'WA' | 'NSW' | 'T' | 'V' | 'NT' | 'SA' | 'Q';
type Color           = 'red' | 'blue' | 'green';

// %% [markdown]
// The function $\texttt{mapColoringCSP}()$ returns a CSP that encodes the *map coloring problem* for Australia.

// %%
function mapColoringCSP(): CSP {
    const variables: AustralianState[] = [
        'WA', 'NSW', 'T', 'V', 'NT', 'SA', 'Q'
    ];
    const values: Color[] = ['red', 'blue', 'green'];
    const constraints: string[] = [
        'WA != NT', 'WA != SA',
        'NT != SA', 'NT != Q',
        'SA != Q', 'SA != NSW', 'SA != V',
        'Q != NSW', 'NSW != V'
    ];
    return { 
        variables, 
        values, 
        constraints 
    };
}

// %%
const csp = mapColoringCSP()
csp
// Out:
// {
//   variables: [
//     'WA', 'NSW',
//     'T',  'V',
//     'NT', 'SA',
//     'Q'
//   ],
//   values: [ 'red', 'blue', 'green' ],
//   constraints: [
//     'WA != NT', 'WA != SA',
//     'NT != SA', 'NT != Q',
//     'SA != Q',  'SA != NSW',
//     'SA != V',  'Q != NSW',
//     'NSW != V'
//   ]
// }

// %% [markdown]
// As there are $3$ different values and $7$ different variables, there are $3^7 = 2187$ different ways to assign values to the variables.

// %%
3 ** 7
// Out:
// 2187

// %% [markdown]
// ## Visualization

// %% [markdown]
// The function `showSolution` takes two parameters:
//  * `Solution` is a partial variable assignment, i.e. it is a dictionary
//    mapping some of the variables to the colors.
//  * `width` specifies the width of the image that will be created,

// %%
import { display } from "tslab";

const AUSTRALIA_PATHS: Record<string, string> = {
    'WA':  "M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z",
    'NT':  "M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z",
    'SA':  "M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z",
    'Q':   "M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z",
    'NSW': "M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z",
    'V':   "M 350,320 L 440,320 L 420,360 L 360,360 Z",
    'T':   "M 390,390 L 420,390 L 410,430 L 380,430 Z"
};
const LABELS: Record<string, { x: number, y: number, lines: string[]}> = {
    'WA':  { x: 140, y: 190, lines: ['Western', 'Australia'] },
    'NT':  { x: 285, y: 130, lines: ['Northern', 'Territory'] },
    'SA':  { x: 290, y: 265, lines: ['South', 'Australia'] },
    'Q':   { x: 390, y: 140, lines: ['Queensland'] },
    'NSW': { x: 395, y: 280, lines: ['New South', 'Wales'] },
    'V':   { x: 395, y: 340, lines: ['Victoria'] },
    'T':   { x: 400, y: 415, lines: ['Tasmania'] }
};

function showSolution(assignment: Assignment): void {
    const colors: Record<string, string> = {
        'red': '#ff8787', 
        'green': '#69db7c', 
        'blue': '#4dabf7',
        'default': '#f1f3f5'
    };
    const svgPaths = Object.keys(AUSTRALIA_PATHS).map(key => {
        const state = key as AustralianState;
        const val = assignment[state];
        const fill = val !== undefined ? (colors[val] || val) : colors['default'];
        return `<path d="${AUSTRALIA_PATHS[state]}" fill="${fill}" stroke="#888" stroke-width="1" />`;
    }).join('');
    const svgLabels = Object.keys(LABELS).map(state => {
        const config = LABELS[state];
        const fontSize = 12;
        const lineHeight = fontSize * 1.2;
        const tspans = config.lines.map((line, i) => {
            const dy = i === 0 ? 0 : lineHeight; 
            return `<tspan x="${config.x}" dy="${i===0 ? 0 : '1.2em'}">${line}</tspan>`;
        }).join('');
        return `
            <text 
                x="${config.x}" 
                y="${config.y}" 
                font-family="Arial, sans-serif" 
                font-size="${fontSize}" 
                font-weight="bold" 
                fill="#343a40" 
                text-anchor="middle" 
                pointer-events="none"
            >
                ${tspans}
            </text>
        `;
    }).join('');
    const html = `
        <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
            <svg width="500" height="450" viewBox="0 0 500 450">
                ${svgPaths}
                ${svgLabels}
            </svg>
        </div>
    `;
    display.html(html);
}

// %%
solve(csp, showSolution);
// Out:
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
// ...
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
// Tested 95 partial assignments
// {
//   steps: 95,
//   solution: {
//     WA: 'red',
//     NSW: 'blue',
//     T: 'red',
//     V: 'red',
//     NT: 'blue',
//     SA: 'green',
//     Q: 'red'
//   }
// }

// %% [markdown]
// Below, we have changed the ordering of the variables.  With this new, the constraint solver never needs to backtrack.

// %%
function mapColoringCSP(): CSP {
    const variables: AustralianState[] = [
        'WA', 'NT', 'SA', 'Q', 'NSW', 'V', 'T'
    ];
    const values: Color[] = ['red', 'blue', 'green'];
    const constraints: string[] = [
        'WA != NT', 'WA != SA',
        'NT != SA', 'NT != Q',
        'SA != Q',  'SA != NSW', 'SA != V',
        'Q != NSW', 'NSW != V'
    ];
    return {
        variables, 
        values, 
        constraints
    };
}

// %%
const csp = mapColoringCSP();
solve(csp, showSolution);
// Out:
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#f1f3f5" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
//         <div style="border: 1px solid #dee2e6; padding: 10px; border-radius: 5px; display: inline-block; background: white;">
//             <svg width="500" height="450" viewBox="0 0 500 450">
//                 <path d="M 190,340 L 180,310 L 130,280 L 60,250 L 40,200 L 60,150 L 90,120 L 150,80 L 240,70 L 240,250 L 210,340 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 240,70 L 330,70 L 340,100 L 330,200 L 240,200 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 240,200 L 330,200 L 330,250 L 360,270 L 350,340 L 290,340 L 260,310 L 210,340 L 240,250 Z" fill="#69db7c" stroke="#888" stroke-width="1" /><path d="M 330,70 L 360,20 L 400,60 L 430,150 L 450,200 L 450,250 L 330,250 L 330,200 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 330,250 L 450,250 L 440,320 L 350,320 L 350,270 Z" fill="#4dabf7" stroke="#888" stroke-width="1" /><path d="M 350,320 L 440,320 L 420,360 L 360,360 Z" fill="#ff8787" stroke="#888" stroke-width="1" /><path d="M 390,390 L 420,390 L 410,430 L 380,430 Z" fill="#ff8787" stroke="#888" stroke-width="1" />
//
//             <text
//                 x="140"
//                 y="190"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="140" dy="0">Western</tspan><tspan x="140" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="285"
//                 y="130"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="285" dy="0">Northern</tspan><tspan x="285" dy="1.2em">Territory</tspan>
//             </text>
//
//             <text
//                 x="290"
//                 y="265"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="290" dy="0">South</tspan><tspan x="290" dy="1.2em">Australia</tspan>
//             </text>
//
//             <text
//                 x="390"
//                 y="140"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="390" dy="0">Queensland</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="280"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">New South</tspan><tspan x="395" dy="1.2em">Wales</tspan>
//             </text>
//
//             <text
//                 x="395"
//                 y="340"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="395" dy="0">Victoria</tspan>
//             </text>
//
//             <text
//                 x="400"
//                 y="415"
//                 font-family="Arial, sans-serif"
//                 font-size="12"
//                 font-weight="bold"
//                 fill="#343a40"
//                 text-anchor="middle"
//                 pointer-events="none"
//             >
//                 <tspan x="400" dy="0">Tasmania</tspan>
//             </text>
//
//             </svg>
//         </div>
// Tested 11 partial assignments
// {
//   steps: 11,
//   solution: {
//     WA: 'red',
//     NT: 'blue',
//     SA: 'green',
//     Q: 'red',
//     NSW: 'blue',
//     V: 'red',
//     T: 'red'
//   }
// }
