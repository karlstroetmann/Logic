// %% [markdown]
// A natural number $n$ is perfect if $n$ is equal to the sum of its proper divisors:
// $$ \sum \bigl\{ t \in \{1,\cdots, n-1\} \,\bigm|\, n \;\texttt{%}\; t = 0 \bigr\}  = n $$
// For example, $6$ is perfect, because $6 = 1 + 2 + 3$, but $8$ is not perfect, because
// $1 + 2 + 4 = 7 \not= 8$.

// %% [markdown]
// $\textsf{Standard} \quad \texttt{Typewriter%} \quad \mathtt{MathType}$

// %%
function perfect(n: number): boolean {
    let sum = 0;
    for (let t = 1; t < n; t++) {
        if (n % t == 0) {
            sum += t;
        }
    }
    return sum == n;
}

// %%
perfect(6)

// %%
perfect(8)

// %%
function findOddPerfect(): number | null {
    let n = 1;
    while (true) {
        if (perfect(n)) {
            return n;
        }
        if (n % 1000 == 1) {
            console.log(n);
        }
        n += 2;
    }
}

// %%
findOddPerfect()
