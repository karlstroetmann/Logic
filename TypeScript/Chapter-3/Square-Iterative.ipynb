// %%
function square(s: number): number {
    let r = 0;
    let u = 1;
    while (s > 0) {
        r += u;
        u += 2;
        s -= 1;
    }
    return r;
}

// %%
for (let i = 0; i <= 11; ++i) {
    console.log(`square(${i}) = ${square(i)}`);
}
